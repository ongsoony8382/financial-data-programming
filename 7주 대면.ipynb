# %% [markdown]
# <a href="https://colab.research.google.com/github/ongsoony8382/financial-data-programming/blob/main/7%EC%A3%BC%20%EB%8C%80%EB%A9%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 금융데이터 분석(7): 7주차 대면수업
#
# # 학습목표
# - 거시경제 분석
# - 보험료 결정요인분석
#
# # 학습내용
# - 국채금리 분석
# - pandas의 pivot table 분석

# %% [markdown]
# # 거시경제의 흐름, 국채금리 분석 (Bond Yields)
# - '채권금리(Yield)' 데이터를 통해 경제 흐름을 읽는 법을 다룸.
# - 특히 경기침체의 신호로 불리는 장단기 금리차를 분석
# # 라이브러리 설치 및 데이터 가져오기
# 채권 데이터는 미 연준(FRED) 데이터를 가져오는 pandas_datareader를 사용.
